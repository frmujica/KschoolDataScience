# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from VulnsCategorization import VulnsCategorizationMain

# %%
PluginsFile = './QualysPlugins/PluginsQualys1901.xml'
OutputFile = './OutputFiles/QualysLookupResult1901.csv'
PluginsQualysConfig = 'QualysApiConfigs/apiconfig.ini'
VendorReferences = '../VendorReferences.csv'

# %%
# %%time
VulnsCategorizationMain('n',PluginsFile,OutputFile,PluginsQualysConfig,VendorReferences)
# Out:
# Using the knowledge base in your localfiles
# File ./OutputFiles/QualysLookupResult1901.csv was created
# CPU times: user 21.3 s, sys: 765 ms, total: 22.1 s
# Wall time: 22.1 s

# %%
pluginsdf = pd.read_csv(OutputFile+'.gz')

# %%
pluginsdf.head()
# Out:
#      ID       SolutionCategory VendorReference              PluginName  \
# 0     6          Informational             NaN           DNS Host Name
# 1     9          Informational             NaN  Open RPC Services List
# 2    11  Configuration changes             NaN     Hidden RPC Services
# 3    32          Informational             NaN          Darxite Banner
# 4  1000  Configuration changes             NaN  Potential UDP Backdoor
#
#                                            Diagnosis  \
# 0  The fully qualified domain name of this host i...
# 1  A port scanner was used to draw a map of all t...
# 2  The Portmapper/Rpcbind listens on port 111 and...
# 3                                               None
# 4  There are known backdoors that use specific po...
#
#                                          Consequence  \
# 0                                               None
# 1  Unauthorized users can subsequently test vulne...
# 2  Unauthorized users can build a list of RPC ser...
# 3                                               None
# 4  If a backdoor is present on your system then u...
#
#                                             Solution
# 0                                               None
# 1  shut down any unknown or unused service on the...
# 2  firewalling the portmapper port or removing th...
# 3                                               None
# 4  call a security specialist and test this host ...

# %%
SolutionCategory = pluginsdf.groupby(['SolutionCategory'])

# %%
SolutionCategory.describe()
# Out:
#                                      ID                                \
#                                   count           mean            std
# SolutionCategory
# Configuration changes            1366.0   54949.222548   69510.404617
# End of life Platform              447.0  108309.572707   54306.485632
# Informational                    1190.0   79307.805882   50221.570693
# No solution or patch available   1529.0   64594.605625   73196.777306
# To classify                        17.0   95577.470588  111255.803948
# Update or patch installation    36360.0  159110.334213   86567.600358
# Workaround                        607.0   67048.131796   67982.173391
#
#                                                                          \
#                                     min        25%       50%        75%
# SolutionCategory
# Configuration changes              11.0   10531.50   34004.5   86385.00
# End of life Platform            11542.0  105420.50  105553.0  105668.50
# Informational                       6.0   45090.25   78019.5  105242.75
# No solution or patch available   1020.0   11331.00   38010.0  115957.00
# To classify                      7009.0   19568.00   62080.0  105089.00
# Update or patch installation     1018.0  117173.75  157118.5  176542.25
# Workaround                       1024.0   12336.00   43401.0  116243.00
#
#
#                                      max
# SolutionCategory
# Configuration changes           371535.0
# End of life Platform            371149.0
# Informational                   370668.0
# No solution or patch available  371349.0
# To classify                     371016.0
# Update or patch installation    390164.0
# Workaround                      371163.0

# %%
SolutionCategory.count().loc[:,['ID']]
# Out:
#                                    ID
# SolutionCategory
# Configuration changes            1366
# End of life Platform              447
# Informational                    1190
# No solution or patch available   1529
# To classify                        17
# Update or patch installation    36360
# Workaround                        607

# %%
SolutionCategory.count().loc[:,['ID']].plot.pie(y='ID',figsize=(10, 10));
